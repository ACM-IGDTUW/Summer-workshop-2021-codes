# %%
# !pip install tweepy

import tweepy

consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''
                   
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.3.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.7.1)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.12.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2020.4.5.2)

# %%
search_results = api.search(q='covid', count=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8acc229f4a90> in <module>()
# ----> 1 search_results = api.search(q='covid', count=20)
#
# NameError: name 'api' is not defined

# %%
for item in search_results:
    print(item._json)
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2f2f6eb2124f> in <module>()
# ----> 1 for item in search_results:
#       2     print(item._json)
#       3     break
#
# NameError: name 'search_results' is not defined

# %%
one_tweet = search_results[0]._json

# %%
result = []
for item in search_results:
    result.append(item._json)

print(result)
# Out:
# [{'created_at': 'Thu Jun 18 06:18:33 +0000 2020', 'id': 1273500329900998657, 'id_str': '1273500329900998657', 'text': "RT @GMB: Public health officials are reviewing Vitamin D's effects on coronavirus.\n\n@DrHilaryJones says there's 'no harm' in taking Vitamin…", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'GMB', 'name': 'Good Morning Britain', 'id': 19424427, 'id_str': '19424427', 'indices': [3, 7]}, {'screen_name': 'DrHilaryJones', 'name': 'Dr. Hilary Jones', 'id': 106068934, 'id_str': '106068934', 'indices': [84, 98]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1206645695777783808, 'id_str': '1206645695777783808', 'name': 'Sibéal Ní Fallúin 🕊🇮🇪🦚🇪🇺', 'screen_name': 'NiSibeal', 'location': 'England, United Kingdom', 'description': 'Independent thinker & Irish diaspora', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 383, 'friends_count': 738, 'listed_count': 0, 'created_at': 'Mon Dec 16 18:42:25 +0000 2019', 'favourites_count': 18875, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 10473, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1255400253295079426/c7GbXE1q_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255400253295079426/c7GbXE1q_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1206645695777783808/1576527271', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Jun 18 06:00:11 +0000 2020', 'id': 1273495705592758272, 'id_str': '1273495705592758272', 'text': "Public health officials are reviewing Vitamin D's effects on coronavirus.\n\n@DrHilaryJones says there's 'no harm' in… https://t.co/kzetfFZBTm", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'DrHilaryJones', 'name': 'Dr. Hilary Jones', 'id': 106068934, 'id_str': '106068934', 'indices': [75, 89]}], 'urls': [{'url': 'https://t.co/kzetfFZBTm', 'expanded_url': 'https://twitter.com/i/web/status/1273495705592758272', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://grabyo.com" rel="nofollow">Grabyo</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19424427, 'id_str': '19424427', 'name': 'Good Morning Britain', 'screen_name': 'GMB', 'location': 'London', 'description': "The UK's most talked about breakfast television show. Weekdays from 6am on @ITV. Replies & content may be used on air. See https://t.co/u4BYxXFfJq", 'url': 'https://t.co/ZZKX14E7X3', 'entities': {'url': {'urls': [{'url': 'https://t.co/ZZKX14E7X3', 'expanded_url': 'http://www.itv.com/gmb', 'display_url': 'itv.com/gmb', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/u4BYxXFfJq', 'expanded_url': 'htt ...

# %%
search_results[18]._json
# Out:
# {'created_at': 'Thu Jun 18 06:18:32 +0000 2020',
#  'id': 1273500326239354880,
#  'id_str': '1273500326239354880',
#  'text': 'RT @monikaalynn_: greg abbott really blamed young people for the spike in covid cases... the man in charge of texas... who OPENED UP TEXAS.…',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'monikaalynn_',
#     'name': '𝙼🍩𝙽𝙸𝙺𝙰',
#     'id': 1631575915,
#     'id_str': '1631575915',
#     'indices': [3, 16]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 865670289727799296,
#   'id_str': '865670289727799296',
#   'name': 'fee🐝',
#   'screen_name': 'phoebejade14',
#   'location': 'FtwTx',
#   'description': 'fuck it, we ball pt. 1',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 456,
#   'friends_count': 349,
#   'listed_count': 0,
#   'created_at': 'Fri May 19 20:47:35 +0000 2017',
#   'favourites_count': 13360,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1814,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1245397379714633729/_BxyZXo7_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1245397379714633729/_BxyZXo7_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/865670289727799296/1590456376',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Tue Jun 16 20:17:47 +0000 2020',
#   'id': 1272986752375029760,
#   'id_str': '1272986752375029760',
#   'text': 'greg abbott really blamed young people for the spike in covid cases... the man in charge of texas... who OPENED UP… https://t.co/wgRDMLBN9c',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/wgRDMLBN9c',
#      'expanded_url': 'https://twitter.com/i/web/status/1272986752375029760',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1631575915,
#    'id_str': '1631575915',
#    'name': '𝙼🍩𝙽𝙸𝙺𝙰',
#    'screen_name': 'monikaalynn_',
#    'location': 'tx',
#    'description': "🇲🇽 || 𝚜𝚎𝚛 𝚌𝚘𝚗𝚏𝚘𝚛𝚖𝚒𝚜𝚝𝚊 𝚎𝚜 𝚕𝚘 𝚖𝚒𝚜𝚖𝚘 𝚚𝚞𝚎 𝚜𝚎𝚛 𝚍𝚎𝚛𝚛𝚘𝚝𝚊𝚍𝚘 -𝙽𝙹𝙶 || utrgv 21' 📚",
#    'url': 'https://t.co/wbwjZTCt9F',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/wbwjZTCt9F',
#        'expanded_url': 'https://docs.google.com/document/d/12q9DfEn185se87KOJXXEu1XP-pFLw5QS0O0qSBSn6pI/mobilebasic',
#        'display_url': 'docs.google.com/document/d/12q…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1048,
#    'friends_count': 678,
#    'listed_count': 3,
#    'created_at': 'Mon Jul 29 23:59:41 +0000 2013',
#    'favourites_count': 61754,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 39115,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1265389506229829634/cvLsAmCk_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1265389506229829634/cvLsAmCk_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1631575915/1589527569',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 6795,
#   'favorite_count': 17484,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 6795,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
one_tweet.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
one_tweet_entitites = one_tweet['entities']

# %%
one_tweet_entitites
# Out:
# {'hashtags': [],
#  'symbols': [],
#  'user_mentions': [{'screen_name': 'GMB',
#    'name': 'Good Morning Britain',
#    'id': 19424427,
#    'id_str': '19424427',
#    'indices': [3, 7]},
#   {'screen_name': 'DrHilaryJones',
#    'name': 'Dr. Hilary Jones',
#    'id': 106068934,
#    'id_str': '106068934',
#    'indices': [84, 98]}],
#  'urls': []}

# %%
all_hashtags = []

for item in search_results:
    print(item._json['entities']['hashtags'])
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [{'text': 'GlobalTalk', 'indices': [0, 11]}]
# []
# []
# []

# %%
one_tweet['user']
# Out:
# {'id': 1206645695777783808,
#  'id_str': '1206645695777783808',
#  'name': 'Sibéal Ní Fallúin 🕊🇮🇪🦚🇪🇺',
#  'screen_name': 'NiSibeal',
#  'location': 'England, United Kingdom',
#  'description': 'Independent thinker & Irish diaspora',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 383,
#  'friends_count': 738,
#  'listed_count': 0,
#  'created_at': 'Mon Dec 16 18:42:25 +0000 2019',
#  'favourites_count': 18875,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 10473,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1255400253295079426/c7GbXE1q_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255400253295079426/c7GbXE1q_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1206645695777783808/1576527271',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
# all_user_ids = []

for tweet in search_results:
    data = tweet._json
    print(data['user']['followers_count'])
# Out:
# 383
# 9652
# 7058
# 202
# 568
# 1246
# 1654
# 818
# 561
# 20822
# 754
# 45
# 9
# 1153
# 559
# 943
# 1173
# 704
# 456
# 2079

# %%
all_user_ids
# Out:
# ['1206645695777783808',
#  '1566650000',
#  '1186901984835592194',
#  '59488525',
#  '1341059894',
#  '311889009',
#  '1656449802',
#  '2363947262',
#  '1106321028',
#  '303413094',
#  '3962970973',
#  '1185270105766121472',
#  '1171517208700211202',
#  '1424440531',
#  '289565648',
#  '50240793',
#  '140601768',
#  '434714494',
#  '865670289727799296',
#  '827288161']

# %%
user_data = api.get_user(id='827288161')
user_data = user_data._json
user_data.keys()
# Out:
# dict_keys(['id', 'id_str', 'name', 'screen_name', 'location', 'profile_location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'follow_request_sent', 'notifications', 'translator_type'])

# %%
def get_user_with_max_followers(hashtag):
    """
    input : hashtag
    output : information of the user with maximum no followers. 
    """

    search_results = api.search(q=hashtag, count=20)
    all_followers = []
    tweets = []
    
    for tweet in search_results:
        data = tweet._json
        followers = data['user']['followers_count']
        all_followers.append(followers)
        tweets.append(data)

    max_no_followers = max(all_followers)
    
    target_person_index = all_followers.index(max_no_followers)
    person_info = tweets[target_person_index]
    user_id = person_info['user']['id_str']

    return api.get_user(id=user_id)._json

# %%
get_user_with_max_followers('covid')
# Out:
# {'id': 22241235,
#  'id_str': '22241235',
#  'name': 'Jorge Amigo',
#  'screen_name': 'AmigoJor',
#  'location': 'Vancouver, British Columbia',
#  'profile_location': None,
#  'description': 'Pre-pandemic hugger. Cyclist, arts aficionado, and incorrigible book hoarder. Cultural programming @VPL. He/him.',
#  'url': 'https://t.co/fRf4F3u3uK',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/fRf4F3u3uK',
#      'expanded_url': 'http://jorgeamigo.com',
#      'display_url': 'jorgeamigo.com',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 3418,
#  'friends_count': 3317,
#  'listed_count': 137,
#  'created_at': 'Sat Feb 28 08:45:43 +0000 2009',
#  'favourites_count': 6967,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': False,
#  'statuses_count': 14274,
#  'lang': None,
#  'status': {'created_at': 'Thu Jun 18 07:26:08 +0000 2020',
#   'id': 1273517337413447680,
#   'id_str': '1273517337413447680',
#   'text': 'RT @forensictoxguy: Has COVID-19 forced you to wear glasses and a mask at the same time?\n\nIf so, you may be entitled to condensation.',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'forensictoxguy',
#      'name': 'Kevin Shanks',
#      'id': 1439590734,
#      'id_str': '1439590734',
#      'indices': [3, 18]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Jun 15 19:09:47 +0000 2020',
#    'id': 1272607251891720209,
#    'id_str': '1272607251891720209',
#    'text': 'Has COVID-19 forced you to wear glasses and a mask at the same time?\n\nIf so, you may be entitled to condensation.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 42870,
#    'favorite_count': 234052,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 42870,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '050505',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1070007053035417600/gr_33I7R_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1070007053035417600/gr_33I7R_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22241235/1499232147',
#  'profile_link_color': 'ABB8C2',
#  'profile_sidebar_border_color': 'BDDCAD',
#  'profile_sidebar_fill_color': 'CCD3FF',
#  'profile_text_color': '570857',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}
